# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv('mytable_customer_details - Table1_CustDetails.csv')

# %%
df.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7049.000000    7049.000000       7049.000000    7049.000000
# mean            0.162009       1.324585          1.222585       0.690878
# std             0.368485       0.642709          0.779068       0.833757
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_charges  total_charges       tenure  partner_dependents
# count      7049.000000    7038.000000  7049.000000         7049.000000
# mean         64.747014    2283.043883    32.379866            1.083416
# std          30.099460    2266.521984    24.595524            1.226883
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7049 non-null   object
#  1   gender                  7049 non-null   object
#  2   is_senior_citizen       7049 non-null   int64
#  3   partner                 7049 non-null   object
#  4   dependents              7049 non-null   object
#  5   phone_service           7049 non-null   int64
#  6   internet_service        7049 non-null   int64
#  7   contract_type           7049 non-null   int64
#  8   payment_type            7049 non-null   object
#  9   monthly_charges         7049 non-null   float64
#  10  total_charges           7038 non-null   float64
#  11  churn                   7049 non-null   object
#  12  tenure                  7049 non-null   float64
#  13  is_female               7049 non-null   bool
#  14  has_churned
# ...

# %%
df.churn.value_counts()
# Out:
# No     5179
# Yes    1870
# Name: churn, dtype: int64

# %%
df_mtm_churned = df[(df.churn == "Yes") &  (df.contract_type==0)]
df_mtm_churned
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# 19    0023-HGHWL    Male                  1      No         No              0
# 21    0023-XUOPT  Female                  0     Yes         No              2
# ...          ...     ...                ...     ...        ...            ...
# 7023  9965-YOKZB    Male                  1      No         No              2
# 7031  0032-PGELS  Female                  0     Yes        Yes              0
# 7042  9985-MWVIX  Female                  0      No         No              1
# 7043  9986-BONCE  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
#
# ...

# %%
df_mtm_churned.payment_type.isin("automatic")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a91a3f8751bd> in <module>
# ----> 1 df_mtm_churned.payment_type.isin("automatic")
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in isin(self, values)
#    4663         dtype: bool
#    4664         """
# -> 4665         result = algorithms.isin(self._values, values)
#    4666         return self._constructor(result, index=self.index).__finalize__(
#    4667             self, method="isin"
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in isin(comps, values)
#     433         )
#     434     if not is_list_like(values):
# --> 435         raise TypeError(
#     436             "only list-like objects are allowed to be passed "
#     437             f"to isin(), you passed a [{type(values).__name__}]"
#
# ...

# %%
           
sns.relplot(x='internet_type', y='customer_id', data= df_mtm_churned)

# %%
# plotting graph
#df.plot(x="churn", y=[count("has_phone"), count("has_internet"), count("has_phone_and_internet")], kind="bar")

# %%
sns.histplot(df.churn)
plt.show()

# %%
sns.histplot(y='churn', x='has_phone', data=df)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:xlabel='has_phone', ylabel='churn'>

# %%
sns.pairplot(df_mtm_churned)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ...
